# %%
import pandas as pd
import numpy as np

# %%
# pd.set_option('display.max_columns', None)  #DELETE

# %%
fifa = pd.read_csv('copy_fifa21_train.csv')
display(fifa.head())

fifa.shape
# Out:
#        ID           Name  Age  Nationality                        Club   BP  \
# 0  184383      A. Pasche   26  Switzerland           FC Lausanne-Sport   CM
# 1  188044  Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC   ST
# 2  184431    S. Giovinco   33        Italy                    Al Hilal  CAM
# 3  233796       J. Evans   22        Wales                Swansea City  CDM
# 4  234799     Y. Demoncy   23       France  US Orléans Loiret Football  CDM
#
#    Position                               Team & Contract Height  Weight  ...  \
# 0    CM CDM                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs  ...
# 1  ST LW LM  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs  ...
# 2    CAM CF                          Al Hilal 2019 ~ 2022   5'4"  134lbs  ...
# 3    CDM CM                      Swansea City 2016 ~ 2021  5'10"  152lbs  ...
# 4    CDM CM        US Orléans Loiret Football 2018 ~ 2021  5'11"  150lbs  ...
#
#     CDM   RDM   RWB    LB   LCB    CB   RCB    RB    GK  OVA
# 0  59+1  59+1  59+1  58+1  54+1  54+1  54+1  58+1  15+1   64
# 1  53+2  53+2  57+2  53+2  48+2  48+2  48+2  53+2  18+2   77
# 2  56+2  56+2  59+2  53+2  41+2  41+2  41+2  53+2  12+2   80
# 3  58+2  58+2  56+2  57+2  58+2  58+2  58+2  57+2  14+2   59
# 4  64+2  64+2  64+2  63+2  61+2  61+2  61+2  63+2  15+2   65
#
# [5 rows x 101 columns]
# (11701, 101)

# %%
fifa.duplicated().sum()
# Out:
# 0

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(fifa.dtypes)
# Out:
# ID                    int64
# Name                 object
# Age                   int64
# Nationality          object
# Club                 object
# BP                   object
# Position             object
# Team & Contract      object
# Height               object
# Weight               object
# foot                 object
# Growth                int64
# Joined               object
# Loan Date End        object
# Value                object
# Wage                 object
# Release Clause       object
# Contract             object
# Attacking             int64
# Crossing              int64
# Finishing             int64
# Heading Accuracy      int64
# Short Passing         int64
# Volleys             float64
# Skill                 int64
# Dribbling             int64
# Curve               float64
# FK Accuracy           int64
# Long Passing          int64
# Ball Control          int64
# Movement              int64
# Acceleration          int64
# Sprint Speed          int64
# Agility             float64
# Reactions             int64
# Balance             float64
# Power                 int64
# Shot Power            int64
# Jumping             float64
# Stamina               int64
# Strength              int64
# Long Shots            int64
# Mentality             int64
# Aggression            int64
# Interceptions       float64
# Positioning         float64
# Vision              float64
# Penalties             int64
# Composure           float64
# Defending             int64
# Marking               int64
# Standing Tackle       int64
# Sliding Tackle      float64
# Goalkeeping           int64
# GK Diving             int64
# GK Handling           int64
# GK Kicking            int64
# GK Positioning        int64
# GK Reflexes           int64
# Total Stats           int64
# Base Stats            int64
# W/F                  object
# SM                   object
# A/W                  object
# D/W                  object
# IR                   object
# PAC                   int64
# SHO                   int64
# PAS                   int64
# DRI                   int64
# DEF                   int64
# PHY                   int64
# Hits                 object
# LS                   object
# ST                   object
# RS                   object
# LW                   object
# LF                   object
# CF                   object
# RF                   object
# RW                   object
# LAM                  object
# CAM                  object
# RAM                  object
# LM                   object
# LCM                  object
# CM                   object
# RCM                  object
# RM                   object
# LWB                  object
# LDM                  object
# CDM                  object
# RDM                  object
# RWB                  object
# LB                   object
# LCB                  object
# CB                   object
# RCB                  object
# RB                   object
# GK                   object
# OVA                   int64
# dtype: object

# %%
fifa.select_dtypes(include=np.number)
# Out:
#            ID  Age  Growth  Attacking  Crossing  Finishing  Heading Accuracy  \
# 0      184383   26       1        258        54         47                43
# 1      188044   30       0        365        66         79                76
# 2      184431   33       0        336        73         76                34
# 3      233796   22      13        242        44         42                58
# 4      234799   23       8        249        49         37                61
# ...       ...  ...     ...        ...       ...        ...               ...
# 11696  232504   25       5        224        62         24                51
# 11697  214680   27       4         84        12         14                13
# 11698  221489   22       8        286        64         66                51
# 11699  146717   26       7        254        64         66                51
# 11700  236507   22       9        289        43         64                65
#
#        Short Passing  Volleys  Skill  ...  GK Reflexes  Total Stats  \
# 0                 70     44.0    286  ...            6         1682
# 1                 68     76.0    375  ...           16         1961
# 2                 78     75.0    424  ...            3         1925
# 3                 62     36.0    259  ...           12         1527
# 4                 68     34.0    280  ...           15         1664
# ...              ...      ...    ...  ...          ...          ...
# 11696             59     28.0    248  ...           14         1589
# 11697             29     16.0     96  ...           72         1123
# 11698             64     41.0    291  ...           16         1603
# 11699             73      NaN    284  ...           24         1429
# 11700             64     53.0    267  ...            8         1607
#
#        Base Stats  PAC  SHO  PAS  DRI  DEF  PHY  OVA
# 0             357   69   51   63   63   51   60   64
# 1             412   83   75   68   82   33   71   77
# 2             404   80   77   78   86   27   56   80
# 3             329   57   44   54   57   57   60   59
# 4             360   66   44   60   64   60   66   65
# ...           ...  ...  ...  ...  ...  ...  ...  ...
# 11696         347   75   28   56   59   60   69   65
# 11697         387   72   67   66   72   40   70   70
# 11698         337   76   60   60   72   26   43   67
# 11699         400   72   63   70   72   57   66   68
# 11700         336   79   62   56   67   24   48   64
#
# [11701 rows x 53 columns]

# %%
fifa.select_dtypes(include=object)
# Out:
#                  Name  Nationality                        Club   BP  \
# 0           A. Pasche  Switzerland           FC Lausanne-Sport   CM
# 1       Alan Carvalho     China PR     Beijing Sinobo Guoan FC   ST
# 2         S. Giovinco        Italy                    Al Hilal  CAM
# 3            J. Evans        Wales                Swansea City  CDM
# 4          Y. Demoncy       France  US Orléans Loiret Football  CDM
# ...               ...          ...                         ...  ...
# 11696   B. Böðvarsson      Iceland       Jagiellonia Białystok   LB
# 11697       G. Gallon       France                ESTAC Troyes   GK
# 11698       J. Flores        Chile              CD Antofagasta   RM
# 11699  Anderson Silva       Brazil                    Barnsley   CM
# 11700     T. Conechny    Argentina            Portland Timbers  CAM
#
#         Position                               Team & Contract Height  Weight  \
# 0         CM CDM                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs
# 1       ST LW LM  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs
# 2         CAM CF                          Al Hilal 2019 ~ 2022   5'4"  134lbs
# 3         CDM CM                      Swansea City 2016 ~ 2021  5'10"  152lbs
# 4         CDM CM        US Orléans Loiret Football 2018 ~ 2021  5'11"  150lbs
# ...          ...                                           ...    ...     ...
# 11696         LB             Jagiellonia Białystok 2018 ~ 2021   6'1"  168lbs
# 11697         GK                      ESTAC Troyes 2019 ~ 2022   6'1"  174lbs
# 11698  LM CAM RM                    CD Antofagasta 2019 ~ 2024   5'6"  143lbs
# 11699        NaN                                 Barnsley 2010   6'2"  179lbs
# 11700  ST CAM LM                  Portland Timbers 2019 ~ 2020   5'7"  143lbs
#
#         foot        Joined  ...   LDM   CDM   RDM   RWB    LB   LCB    CB  \
# 0      Right   Jul 1, 2015  ...  59+1  59+1  59+1  59+1  58+1  54+1  54+1
# 1      Right  Jan 16, 2015  ...  53+2  53+2  53+2  57+2  53+2  48+2  48+2
# 2      Right  Jan 31, 2019  ...  56+2  56+2  56+2  59+2  53+2  41+2  41+2
# 3      Right   Jul 1, 2016  ...  58+2  58+2  58+2  56+2  57+2  58+2  58+2
# 4      Right   Jul 1, 2018  ...  64+2  64+2  64+2  64+2  63+2  61+2  61+2
# ...      ...           ...  ...   ...   ...   ...   ...   ...   ...   ...
# 11696   Left   Feb 8, 2018  ...  60+2  60+2  60+2  63+2  63+2  61+2  61+2
# 11697  Right   Jul 1, 2019  ...  26+2  26+2  26+2  25+2  24+2  26+2  26+2
# 11698  Right  Jan 23, 2019  ...  44+2  44+2  44+2  49+2  45+2  35+2  35+2
# 11699  Right           NaN  ...  68+0  68+0  68+0  66+0  64+0  60+0  60+0
# 11700   Left  Jul 22, 2019  ...  43+2  43+2  43+2  46+2  44+2  36+2  36+2
#
#         RCB    RB    GK
# 0      54+1  58+1  15+1
# 1      48+2  53+2  18+2
# 2      41+2  53+2  12+2
# 3      58+2  57+2  14+2
# 4      61+2  63+2  15+2
# ...     ...   ...   ...
# 11696  61+2  63+2  16+2
# 11697  26+2  24+2  69+2
# 11698  35+2  45+2  17+2
# 11699  60+0  64+0  25+0
# 11700  36+2  44+2  15+2
#
# [11701 rows x 48 columns]

# %%
fifa1 = fifa.drop(columns=['Wage', 'Position','Growth', 'Value', 'ID', 'Name', 'Nationality', 'Club', 'Team & Contract', "Joined", "Loan Date End", "Release Clause", "Contract", "A/W", "D/W"], axis=1)

# %%
cols1 = []
for column in fifa1.columns:
    cols1.append(column.lower())
cols1
fifa1.columns = cols1

fifa1.head()

fifa1
# Out:
#        age   bp height  weight   foot  attacking  crossing  finishing  \
# 0       26   CM   5'9"  161lbs  Right        258        54         47
# 1       30   ST   6'0"  159lbs  Right        365        66         79
# 2       33  CAM   5'4"  134lbs  Right        336        73         76
# 3       22  CDM  5'10"  152lbs  Right        242        44         42
# 4       23  CDM  5'11"  150lbs  Right        249        49         37
# ...    ...  ...    ...     ...    ...        ...       ...        ...
# 11696   25   LB   6'1"  168lbs   Left        224        62         24
# 11697   27   GK   6'1"  174lbs  Right         84        12         14
# 11698   22   RM   5'6"  143lbs  Right        286        64         66
# 11699   26   CM   6'2"  179lbs  Right        254        64         66
# 11700   22  CAM   5'7"  143lbs   Left        289        43         64
#
#        heading accuracy  short passing  ...   cdm   rdm   rwb    lb   lcb  \
# 0                    43             70  ...  59+1  59+1  59+1  58+1  54+1
# 1                    76             68  ...  53+2  53+2  57+2  53+2  48+2
# 2                    34             78  ...  56+2  56+2  59+2  53+2  41+2
# 3                    58             62  ...  58+2  58+2  56+2  57+2  58+2
# 4                    61             68  ...  64+2  64+2  64+2  63+2  61+2
# ...                 ...            ...  ...   ...   ...   ...   ...   ...
# 11696                51             59  ...  60+2  60+2  63+2  63+2  61+2
# 11697                13             29  ...  26+2  26+2  25+2  24+2  26+2
# 11698                51             64  ...  44+2  44+2  49+2  45+2  35+2
# 11699                51             73  ...  68+0  68+0  66+0  64+0  60+0
# 11700                65             64  ...  43+2  43+2  46+2  44+2  36+2
#
#          cb   rcb    rb    gk  ova
# 0      54+1  54+1  58+1  15+1   64
# 1      48+2  48+2  53+2  18+2   77
# 2      41+2  41+2  53+2  12+2   80
# 3      58+2  58+2  57+2  14+2   59
# 4      61+2  61+2  63+2  15+2   65
# ...     ...   ...   ...   ...  ...
# 11696  61+2  61+2  63+2  16+2   65
# 11697  26+2  26+2  24+2  69+2   70
# 11698  35+2  35+2  45+2  17+2   67
# 11699  60+0  60+0  64+0  25+0   68
# 11700  36+2  36+2  44+2  15+2   64
#
# [11701 rows x 86 columns]

# %%
fifa1['hits'] = fifa1['hits'].apply(pd.to_numeric, errors='coerce')

# %%
fifa1.select_dtypes(include=np.number)
# Out:
#        age  attacking  crossing  finishing  heading accuracy  short passing  \
# 0       26        258        54         47                43             70
# 1       30        365        66         79                76             68
# 2       33        336        73         76                34             78
# 3       22        242        44         42                58             62
# 4       23        249        49         37                61             68
# ...    ...        ...       ...        ...               ...            ...
# 11696   25        224        62         24                51             59
# 11697   27         84        12         14                13             29
# 11698   22        286        64         66                51             64
# 11699   26        254        64         66                51             73
# 11700   22        289        43         64                65             64
#
#        volleys  skill  dribbling  curve  ...  total stats  base stats  pac  \
# 0         44.0    286         61   44.0  ...         1682         357   69
# 1         76.0    375         83   78.0  ...         1961         412   83
# 2         75.0    424         85   89.0  ...         1925         404   80
# 3         36.0    259         54   41.0  ...         1527         329   57
# 4         34.0    280         64   44.0  ...         1664         360   66
# ...        ...    ...        ...    ...  ...          ...         ...  ...
# 11696     28.0    248         57   49.0  ...         1589         347   75
# 11697     16.0     96         17   15.0  ...         1123         387   72
# 11698     41.0    291         71   57.0  ...         1603         337   76
# 11699      NaN    284         74    NaN  ...         1429         400   72
# 11700     53.0    267         64   41.0  ...         1607         336   79
#
#        sho  pas  dri  def  phy  hits  ova
# 0       51   63   63   51   60   3.0   64
# 1       75   68   82   33   71  44.0   77
# 2       77   78   86   27   56  73.0   80
# 3       44   54   57   57   60   7.0   59
# 4       44   60   64   60   66   4.0   65
# ...    ...  ...  ...  ...  ...   ...  ...
# 11696   28   56   59   60   69   3.0   65
# 11697   67   66   72   40   70   3.0   70
# 11698   60   60   72   26   43   6.0   67
# 11699   63   70   72   57   66   3.0   68
# 11700   62   56   67   24   48   8.0   64
#
# [11701 rows x 52 columns]

# %%
fifa1.select_dtypes(include=object)
# Out:
#         bp height  weight   foot  w/f  sm   ir    ls    st    rs  ...   ldm  \
# 0       CM   5'9"  161lbs  Right  4 ★  2★  1 ★  58+1  58+1  58+1  ...  59+1
# 1       ST   6'0"  159lbs  Right  3 ★  4★  2 ★  77+0  77+0  77+0  ...  53+2
# 2      CAM   5'4"  134lbs  Right  4 ★  4★  2 ★  73+2  73+2  73+2  ...  56+2
# 3      CDM  5'10"  152lbs  Right  2 ★  2★  1 ★  50+2  50+2  50+2  ...  58+2
# 4      CDM  5'11"  150lbs  Right  2 ★  3★  1 ★  56+2  56+2  56+2  ...  64+2
# ...    ...    ...     ...    ...  ...  ..  ...   ...   ...   ...  ...   ...
# 11696   LB   6'1"  168lbs   Left  3 ★  2★  1 ★  48+2  48+2  48+2  ...  60+2
# 11697   GK   6'1"  174lbs  Right  2 ★  1★  1 ★  28+2  28+2  28+2  ...  26+2
# 11698   RM   5'6"  143lbs  Right  3 ★  3★  1 ★  62+2  62+2  62+2  ...  44+2
# 11699   CM   6'2"  179lbs  Right  3 ★  1★  3 ★  68+0  68+0  68+0  ...  68+0
# 11700  CAM   5'7"  143lbs   Left  3 ★  3★  1 ★  64+2  64+2  64+2  ...  43+2
#
#         cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk
# 0      59+1  59+1  59+1  58+1  54+1  54+1  54+1  58+1  15+1
# 1      53+2  53+2  57+2  53+2  48+2  48+2  48+2  53+2  18+2
# 2      56+2  56+2  59+2  53+2  41+2  41+2  41+2  53+2  12+2
# 3      58+2  58+2  56+2  57+2  58+2  58+2  58+2  57+2  14+2
# 4      64+2  64+2  64+2  63+2  61+2  61+2  61+2  63+2  15+2
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 11696  60+2  60+2  63+2  63+2  61+2  61+2  61+2  63+2  16+2
# 11697  26+2  26+2  25+2  24+2  26+2  26+2  26+2  24+2  69+2
# 11698  44+2  44+2  49+2  45+2  35+2  35+2  35+2  45+2  17+2
# 11699  68+0  68+0  66+0  64+0  60+0  60+0  60+0  64+0  25+0
# 11700  43+2  43+2  46+2  44+2  36+2  36+2  36+2  44+2  15+2
#
# [11701 rows x 34 columns]

# %%
fifa1['w/f'] = fifa1['w/f'].str.rstrip("★").astype(float)
fifa1['sm'] = fifa1['sm'].str.rstrip("★").astype(float)
fifa1['ir'] = fifa1['ir'].str.rstrip("★").astype(float)
fifa1
# Out:
#        age   bp height  weight   foot  attacking  crossing  finishing  \
# 0       26   CM   5'9"  161lbs  Right        258        54         47
# 1       30   ST   6'0"  159lbs  Right        365        66         79
# 2       33  CAM   5'4"  134lbs  Right        336        73         76
# 3       22  CDM  5'10"  152lbs  Right        242        44         42
# 4       23  CDM  5'11"  150lbs  Right        249        49         37
# ...    ...  ...    ...     ...    ...        ...       ...        ...
# 11696   25   LB   6'1"  168lbs   Left        224        62         24
# 11697   27   GK   6'1"  174lbs  Right         84        12         14
# 11698   22   RM   5'6"  143lbs  Right        286        64         66
# 11699   26   CM   6'2"  179lbs  Right        254        64         66
# 11700   22  CAM   5'7"  143lbs   Left        289        43         64
#
#        heading accuracy  short passing  ...   cdm   rdm   rwb    lb   lcb  \
# 0                    43             70  ...  59+1  59+1  59+1  58+1  54+1
# 1                    76             68  ...  53+2  53+2  57+2  53+2  48+2
# 2                    34             78  ...  56+2  56+2  59+2  53+2  41+2
# 3                    58             62  ...  58+2  58+2  56+2  57+2  58+2
# 4                    61             68  ...  64+2  64+2  64+2  63+2  61+2
# ...                 ...            ...  ...   ...   ...   ...   ...   ...
# 11696                51             59  ...  60+2  60+2  63+2  63+2  61+2
# 11697                13             29  ...  26+2  26+2  25+2  24+2  26+2
# 11698                51             64  ...  44+2  44+2  49+2  45+2  35+2
# 11699                51             73  ...  68+0  68+0  66+0  64+0  60+0
# 11700                65             64  ...  43+2  43+2  46+2  44+2  36+2
#
#          cb   rcb    rb    gk  ova
# 0      54+1  54+1  58+1  15+1   64
# 1      48+2  48+2  53+2  18+2   77
# 2      41+2  41+2  53+2  12+2   80
# 3      58+2  58+2  57+2  14+2   59
# 4      61+2  61+2  63+2  15+2   65
# ...     ...   ...   ...   ...  ...
# 11696  61+2  61+2  63+2  16+2   65
# 11697  26+2  26+2  24+2  69+2   70
# 11698  35+2  35+2  45+2  17+2   67
# 11699  60+0  60+0  64+0  25+0   68
# 11700  36+2  36+2  44+2  15+2   64
#
# [11701 rows x 86 columns]

# %%
cols = ['ls','st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk']
for col in cols:
    fifa1[col] = fifa1[col].apply(lambda x:x.split("+")[0])

# %%
fifa1[cols] = fifa1[cols].apply(pd.to_numeric, errors='coerce')

# %%
fifa1
# Out:
#        age   bp height  weight   foot  attacking  crossing  finishing  \
# 0       26   CM   5'9"  161lbs  Right        258        54         47
# 1       30   ST   6'0"  159lbs  Right        365        66         79
# 2       33  CAM   5'4"  134lbs  Right        336        73         76
# 3       22  CDM  5'10"  152lbs  Right        242        44         42
# 4       23  CDM  5'11"  150lbs  Right        249        49         37
# ...    ...  ...    ...     ...    ...        ...       ...        ...
# 11696   25   LB   6'1"  168lbs   Left        224        62         24
# 11697   27   GK   6'1"  174lbs  Right         84        12         14
# 11698   22   RM   5'6"  143lbs  Right        286        64         66
# 11699   26   CM   6'2"  179lbs  Right        254        64         66
# 11700   22  CAM   5'7"  143lbs   Left        289        43         64
#
#        heading accuracy  short passing  ...  cdm  rdm  rwb  lb  lcb  cb  rcb  \
# 0                    43             70  ...   59   59   59  58   54  54   54
# 1                    76             68  ...   53   53   57  53   48  48   48
# 2                    34             78  ...   56   56   59  53   41  41   41
# 3                    58             62  ...   58   58   56  57   58  58   58
# 4                    61             68  ...   64   64   64  63   61  61   61
# ...                 ...            ...  ...  ...  ...  ...  ..  ...  ..  ...
# 11696                51             59  ...   60   60   63  63   61  61   61
# 11697                13             29  ...   26   26   25  24   26  26   26
# 11698                51             64  ...   44   44   49  45   35  35   35
# 11699                51             73  ...   68   68   66  64   60  60   60
# 11700                65             64  ...   43   43   46  44   36  36   36
#
#        rb  gk  ova
# 0      58  15   64
# 1      53  18   77
# 2      53  12   80
# 3      57  14   59
# 4      63  15   65
# ...    ..  ..  ...
# 11696  63  16   65
# 11697  24  69   70
# 11698  45  17   67
# 11699  64  25   68
# 11700  44  15   64
#
# [11701 rows x 86 columns]

# %%
fifa1['height'] = (fifa1['height'].str.extract(r'(\d+)\'\s*(\d+)"').astype(float).mul([12*2.54, 2.54]).sum(axis=1))

# %%
fifa1['weight'] = fifa1['weight'].str.rstrip("lbs").astype(float)/2.2

# %%
fifa1
# Out:
#        age   bp  height     weight   foot  attacking  crossing  finishing  \
# 0       26   CM  175.26  73.181818  Right        258        54         47
# 1       30   ST  182.88  72.272727  Right        365        66         79
# 2       33  CAM  162.56  60.909091  Right        336        73         76
# 3       22  CDM  177.80  69.090909  Right        242        44         42
# 4       23  CDM  180.34  68.181818  Right        249        49         37
# ...    ...  ...     ...        ...    ...        ...       ...        ...
# 11696   25   LB  185.42  76.363636   Left        224        62         24
# 11697   27   GK  185.42  79.090909  Right         84        12         14
# 11698   22   RM  167.64  65.000000  Right        286        64         66
# 11699   26   CM  187.96  81.363636  Right        254        64         66
# 11700   22  CAM  170.18  65.000000   Left        289        43         64
#
#        heading accuracy  short passing  ...  cdm  rdm  rwb  lb  lcb  cb  rcb  \
# 0                    43             70  ...   59   59   59  58   54  54   54
# 1                    76             68  ...   53   53   57  53   48  48   48
# 2                    34             78  ...   56   56   59  53   41  41   41
# 3                    58             62  ...   58   58   56  57   58  58   58
# 4                    61             68  ...   64   64   64  63   61  61   61
# ...                 ...            ...  ...  ...  ...  ...  ..  ...  ..  ...
# 11696                51             59  ...   60   60   63  63   61  61   61
# 11697                13             29  ...   26   26   25  24   26  26   26
# 11698                51             64  ...   44   44   49  45   35  35   35
# 11699                51             73  ...   68   68   66  64   60  60   60
# 11700                65             64  ...   43   43   46  44   36  36   36
#
#        rb  gk  ova
# 0      58  15   64
# 1      53  18   77
# 2      53  12   80
# 3      57  14   59
# 4      63  15   65
# ...    ..  ..  ...
# 11696  63  16   65
# 11697  24  69   70
# 11698  45  17   67
# 11699  64  25   68
# 11700  44  15   64
#
# [11701 rows x 86 columns]

# %%
nulls_df = pd.DataFrame(round(fifa1.isna().sum()/len(fifa1),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#    header_name  percent_nulls
# 0          age            0.0
# 1           bp            0.0
# 2       height            0.0
# 3       weight            0.0
# 4         foot            0.0
# ..         ...            ...
# 81          cb            0.0
# 82         rcb            0.0
# 83          rb            0.0
# 84          gk            0.0
# 85         ova            0.0
#
# [86 rows x 2 columns]

# %%
fifa1.select_dtypes(include=np.number)
# Out:
#        age  height     weight  attacking  crossing  finishing  \
# 0       26  175.26  73.181818        258        54         47
# 1       30  182.88  72.272727        365        66         79
# 2       33  162.56  60.909091        336        73         76
# 3       22  177.80  69.090909        242        44         42
# 4       23  180.34  68.181818        249        49         37
# ...    ...     ...        ...        ...       ...        ...
# 11696   25  185.42  76.363636        224        62         24
# 11697   27  185.42  79.090909         84        12         14
# 11698   22  167.64  65.000000        286        64         66
# 11699   26  187.96  81.363636        254        64         66
# 11700   22  170.18  65.000000        289        43         64
#
#        heading accuracy  short passing  volleys  skill  ...  cdm  rdm  rwb  \
# 0                    43             70     44.0    286  ...   59   59   59
# 1                    76             68     76.0    375  ...   53   53   57
# 2                    34             78     75.0    424  ...   56   56   59
# 3                    58             62     36.0    259  ...   58   58   56
# 4                    61             68     34.0    280  ...   64   64   64
# ...                 ...            ...      ...    ...  ...  ...  ...  ...
# 11696                51             59     28.0    248  ...   60   60   63
# 11697                13             29     16.0     96  ...   26   26   25
# 11698                51             64     41.0    291  ...   44   44   49
# 11699                51             73      NaN    284  ...   68   68   66
# 11700                65             64     53.0    267  ...   43   43   46
#
#        lb  lcb  cb  rcb  rb  gk  ova
# 0      58   54  54   54  58  15   64
# 1      53   48  48   48  53  18   77
# 2      53   41  41   41  53  12   80
# 3      57   58  58   58  57  14   59
# 4      63   61  61   61  63  15   65
# ...    ..  ...  ..  ...  ..  ..  ...
# 11696  63   61  61   61  63  16   65
# 11697  24   26  26   26  24  69   70
# 11698  45   35  35   35  45  17   67
# 11699  64   60  60   60  64  25   68
# 11700  44   36  36   36  44  15   64
#
# [11701 rows x 84 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(fifa.dtypes)
# Out:
# ID                    int64
# Name                 object
# Age                   int64
# Nationality          object
# Club                 object
# BP                   object
# Position             object
# Team & Contract      object
# Height               object
# Weight               object
# foot                 object
# Growth                int64
# Joined               object
# Loan Date End        object
# Value                object
# Wage                 object
# Release Clause       object
# Contract             object
# Attacking             int64
# Crossing              int64
# Finishing             int64
# Heading Accuracy      int64
# Short Passing         int64
# Volleys             float64
# Skill                 int64
# Dribbling             int64
# Curve               float64
# FK Accuracy           int64
# Long Passing          int64
# Ball Control          int64
# Movement              int64
# Acceleration          int64
# Sprint Speed          int64
# Agility             float64
# Reactions             int64
# Balance             float64
# Power                 int64
# Shot Power            int64
# Jumping             float64
# Stamina               int64
# Strength              int64
# Long Shots            int64
# Mentality             int64
# Aggression            int64
# Interceptions       float64
# Positioning         float64
# Vision              float64
# Penalties             int64
# Composure           float64
# Defending             int64
# Marking               int64
# Standing Tackle       int64
# Sliding Tackle      float64
# Goalkeeping           int64
# GK Diving             int64
# GK Handling           int64
# GK Kicking            int64
# GK Positioning        int64
# GK Reflexes           int64
# Total Stats           int64
# Base Stats            int64
# W/F                  object
# SM                   object
# A/W                  object
# D/W                  object
# IR                   object
# PAC                   int64
# SHO                   int64
# PAS                   int64
# DRI                   int64
# DEF                   int64
# PHY                   int64
# Hits                 object
# LS                   object
# ST                   object
# RS                   object
# LW                   object
# LF                   object
# CF                   object
# RF                   object
# RW                   object
# LAM                  object
# CAM                  object
# RAM                  object
# LM                   object
# LCM                  object
# CM                   object
# RCM                  object
# RM                   object
# LWB                  object
# LDM                  object
# CDM                  object
# RDM                  object
# RWB                  object
# LB                   object
# LCB                  object
# CB                   object
# RCB                  object
# RB                   object
# GK                   object
# OVA                   int64
# dtype: object

# %%
fifa1.select_dtypes(include=object)
# Out:
#         bp   foot
# 0       CM  Right
# 1       ST  Right
# 2      CAM  Right
# 3      CDM  Right
# 4      CDM  Right
# ...    ...    ...
# 11696   LB   Left
# 11697   GK  Right
# 11698   RM  Right
# 11699   CM  Right
# 11700  CAM   Left
#
# [11701 rows x 2 columns]

# %%
round(fifa1.isna().sum()/len(fifa1),4)*100
# Out:
# age       0.0
# bp        0.0
# height    0.0
# weight    0.0
# foot      0.0
#          ...
# cb        0.0
# rcb       0.0
# rb        0.0
# gk        0.0
# ova       0.0
# Length: 86, dtype: float64

# %%
fifa1.isna().sum()
# Out:
# age       0
# bp        0
# height    0
# weight    0
# foot      0
#          ..
# cb        0
# rcb       0
# rb        0
# gk        0
# ova       0
# Length: 86, dtype: int64

# %%
replace_NaN = nulls_df[nulls_df['percent_nulls']>1]['header_name']  
print(replace_NaN.values)
# Out:
# ['composure']

# %%
fifa1
# Out:
#        age   bp  height     weight   foot  attacking  crossing  finishing  \
# 0       26   CM  175.26  73.181818  Right        258        54         47
# 1       30   ST  182.88  72.272727  Right        365        66         79
# 2       33  CAM  162.56  60.909091  Right        336        73         76
# 3       22  CDM  177.80  69.090909  Right        242        44         42
# 4       23  CDM  180.34  68.181818  Right        249        49         37
# ...    ...  ...     ...        ...    ...        ...       ...        ...
# 11696   25   LB  185.42  76.363636   Left        224        62         24
# 11697   27   GK  185.42  79.090909  Right         84        12         14
# 11698   22   RM  167.64  65.000000  Right        286        64         66
# 11699   26   CM  187.96  81.363636  Right        254        64         66
# 11700   22  CAM  170.18  65.000000   Left        289        43         64
#
#        heading accuracy  short passing  ...  cdm  rdm  rwb  lb  lcb  cb  rcb  \
# 0                    43             70  ...   59   59   59  58   54  54   54
# 1                    76             68  ...   53   53   57  53   48  48   48
# 2                    34             78  ...   56   56   59  53   41  41   41
# 3                    58             62  ...   58   58   56  57   58  58   58
# 4                    61             68  ...   64   64   64  63   61  61   61
# ...                 ...            ...  ...  ...  ...  ...  ..  ...  ..  ...
# 11696                51             59  ...   60   60   63  63   61  61   61
# 11697                13             29  ...   26   26   25  24   26  26   26
# 11698                51             64  ...   44   44   49  45   35  35   35
# 11699                51             73  ...   68   68   66  64   60  60   60
# 11700                65             64  ...   43   43   46  44   36  36   36
#
#        rb  gk  ova
# 0      58  15   64
# 1      53  18   77
# 2      53  12   80
# 3      57  14   59
# 4      63  15   65
# ...    ..  ..  ...
# 11696  63  16   65
# 11697  24  69   70
# 11698  45  17   67
# 11699  64  25   68
# 11700  44  15   64
#
# [11701 rows x 86 columns]

# %%
columns_drop = nulls_df[nulls_df['percent_nulls']<1]['header_name']  
print(columns_drop.values)
# Out:
# ['age' 'bp' 'height' 'weight' 'foot' 'attacking' 'crossing' 'finishing'
#  'heading accuracy' 'short passing' 'volleys' 'skill' 'dribbling' 'curve'
#  'fk accuracy' 'long passing' 'ball control' 'movement' 'acceleration'
#  'sprint speed' 'agility' 'reactions' 'balance' 'power' 'shot power'
#  'jumping' 'stamina' 'strength' 'long shots' 'mentality' 'aggression'
#  'interceptions' 'positioning' 'vision' 'penalties' 'defending' 'marking'
#  'standing tackle' 'sliding tackle' 'goalkeeping' 'gk diving'
#  'gk handling' 'gk kicking' 'gk positioning' 'gk reflexes' 'total stats'
#  'base stats' 'w/f' 'sm' 'ir' 'pac' 'sho' 'pas' 'dri' 'def' 'phy' 'hits'
#  'ls' 'st' 'rs' 'lw' 'lf' 'cf' 'rf' 'rw' 'lam' 'cam' 'ram' 'lm' 'lcm' 'cm'
#  'rcm' 'rm' 'lwb' 'ldm' 'cdm' 'rdm' 'rwb' 'lb' 'lcb' 'cb' 'rcb' 'rb' 'gk'
#  'ova']

# %%
fifa1['position'].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'position'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 fifa1['position'].value_counts(dropna=False)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3506, in DataFrame.__getitem__(self, key)
#    3504 if self.columns.nlevels > 1:
#    3505     return self._getitem_multilevel(key)
# -> 3506 indexer = self.columns.get_loc(key)
#    3507 if is_integer(indexer):
#    3508     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'position'

# %%
fifa1['position']=fifa1['position'].fillna('CB')

# %%
fifa1['composure'].value_counts(dropna=False)

# %%
median_composure = fifa1['composure'].median()
median_composure

# %%
fifa1['composure'] = fifa1['composure'].fillna(median_composure)

# %%
nulls_df = pd.DataFrame(round(fifa1.isna().sum()/len(fifa1),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(nulls_df)

# %%
 fifa1.isna().sum().sum()

# %%
fifa1= fifa1.dropna()
fifa1

# %%
fifa1.isna().sum().sum()

# %% [markdown]
# ### PROCESSING DATA.

# %% [markdown]
# #### Dealing with outliers.

# %%
categorial_heads = fifa1.select_dtypes(include=['object']).columns.tolist()
print(categorial_heads)

# %%
fifa1['position'].value_counts()

# %%
fifa1 = fifa1.drop('position', axis=1)

# %% [markdown]
# ### Normalization.

# %%
import seaborn as sns
numericals = fifa1.select_dtypes(include=np.number)

# %%
correlations_matrix = numericals.corr() # displaying the correlation matrix
correlations_matrix

# %%
sns.heatmap(correlations_matrix, annot=True) # displaying the heatmap
plt.show()

# %%
import pandas as pd

# Define the columns to check for correlation
columns_to_check = ['rw', 'lw', 'cf', 'rf', 'lf', 'rs', 'ls', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb']

# Calculate the correlation matrix
correlations = fifa1[columns_to_check].corr()

# Find pairs with correlation > 0.9
high_corr = []
for i in range(len(correlations.columns)):
    for j in range(i):
        if abs(correlations.iloc[i, j]) > 0.9:
            colname1 = correlations.columns[i]
            colname2 = correlations.index[j]
            high_corr.append((colname1, colname2))

# Print the pairs with high correlation
print(high_corr)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
y = fifa1['ova'] #defining x-y split
X = fifa1.drop(['ova'], axis=1)
X_num = X.select_dtypes(include = np.number)

# %%
transformer = MinMaxScaler().fit(X_num) 
x_normalized = transformer.transform(X_num)
print(x_normalized.shape)
x_normalized1 = pd.DataFrame(x_normalized, columns=X_num.columns)
x_normalized1

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn import linear_model

# %%
X_cat = fifa1.select_dtypes(include=object)

# %%
#categorical features and numerical ones are going to be treated differently
X_num = X.select_dtypes(include = np.number)
X_cat = X.select_dtypes(include = object)

# %%
X_cat

# %%
encoder = OneHotEncoder(drop='first').fit(X_cat)

cols = encoder.get_feature_names_out(input_features=X_cat.columns)

X_cat_encode = pd.DataFrame(encoder.transform(X_cat).toarray(),columns=cols)

X_cat_encode.head()

# %%
X_cat_encode.shape

# %%
###Concatenating

# %%
X = pd.concat([X_cat_encode, x_normalized1], axis=1)
X

# %%
###Spliting the data ibto test and train samples

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
lm = linear_model.LinearRegression()
lm.fit(X_train,y_train)

# %%
from sklearn.metrics import r2_score
predictions = lm.predict(X_train)
r2_score(y_train, predictions)

# %%
predictions

# %%
predictions_test = lm.predict(X_test)
r2_score(y_test, predictions_test)

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,predictions_test)
mse

# %%
rmse = np.sqrt(mean_squared_error(y_test,predictions_test))
rmse

# %%
y_test.mean()

# %%
from sklearn.metrics import mean_absolute_error, r2_score
mae = mean_absolute_error(y_test, predictions_test)
print(mae)

# %%
# when and how i need to Remove the variable I need to predict? from test and validation part?

# %%
## VALIDATION

# %%
fifa_valid = pd.read_csv('fifa21_validate.csv')
display(fifa_valid.head())
fifa_valid.shape

# %%
fifa_valid = pd.read_csv('fifa21_validate.csv')
display(fifa_valid.head())
fifa_valid.shape

# %%
fifa_valid = pd.read_csv('fifa21_validate.csv')
display(fifa_valid.head())
fifa_valid.shape

# %%
#def clean_data(df):
    #df.columns=[e.lower() for e in df.columns]
    #df=df.drop(columns=['position', 'wage', 'growth', 'value', 'id', 'name', 'nationality', 'club', 'team & contract', "joined", "loan date end", "release clause", "contract", "a/w", "d/w"], axis=1])
    #df.median_composure = fifa_valid['composure'].median()
    #df['composure'] = fifa_valid['composure'].fillna(df.median_composure)
    #df=df.dropna()

# %%
fifa_valid = fifa_valid.drop(columns=['Wage', 'Growth', 'Value', 'ID', 'Name', 'Nationality', 'Position', 'Club', 'Team & Contract', "Joined", "Loan Date End", "Release Clause", "Contract", "A/W", "D/W"], axis=1)

# %%
cols2 = []
for column in fifa_valid.columns:
    cols2.append(column.lower())
cols2
fifa_valid.columns = cols2

fifa_valid.head()

# %%
fifa_valid['w/f'] = fifa_valid['w/f'].str.rstrip("★").astype(float)
fifa_valid['sm'] = fifa_valid['sm'].str.rstrip("★").astype(float)
fifa_valid['ir'] = fifa_valid['ir'].str.rstrip("★").astype(float)
fifa_valid

# %%
fifa_valid['height'] = (fifa_valid['height'].str.extract(r'(\d+)\'\s*(\d+)"').astype(float).mul([12*2.54, 2.54]).sum(axis=1))

# %%
fifa_valid['weight'] = fifa_valid['weight'].str.rstrip("lbs").astype(float)/2.2

# %%
cols2 = ['ls','st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk']
for col in cols2:
    fifa_valid[col] = fifa_valid[col].apply(lambda x:x.split("+")[0])

# %%
fifa_valid[cols2] = fifa_valid[cols2].apply(pd.to_numeric, errors='coerce')

# %%
fifa_valid['hits'] = fifa_valid['hits'].apply(pd.to_numeric, errors='coerce')

# %%
fifa_valid['height'] = (fifa_valid['height'].str.extract(r'(\d+)\'\s*(\d+)"').astype(float).mul([12*2.54, 2.54]).sum(axis=1))

# %%
## 12.15
nulls_df = pd.DataFrame(round(fifa_valid.isna().sum()/len(fifa1),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df

# %%
fifa1['composure'].value_counts(dropna=False)

# %%
median_composure = fifa1['composure'].median()
median_composure

# %%
fifa1['composure'] = fifa1['composure'].fillna(median_composure)

# %%
fifa1.isna().sum().sum()

# %%
fifa1= fifa1.dropna()
fifa1

# %%
X_valid_num = fifa_valid.select_dtypes(include = np.number)
X_valid_cat = fifa_valid.select_dtypes(include = object)

# %%
from sklearn.preprocessing import MinMaxScaler
MinMaxtransformer = MinMaxScaler().fit(X_num)#Training
X_normalized = MinMaxtransformer.transform(X_num) # Implementing
print(type(X_normalized))
X_normalized = pd.DataFrame(X_normalized,columns=X_num.columns)
display(X_normalized.head())
print(type(X_normalized))

# %%
x_valid_num = fifa

# %%
encoder = OneHotEncoder(drop='first').fit(X_valid_cat)

cols = encoder.get_feature_names_out(input_features=X_cat.columns)

X_cat_encode1 = pd.DataFrame(encoder.transform(X_valid_cat).toarray(),columns=cols)

X_cat_encode1.head()

# %%
transformer = MinMaxScaler().fit(X_valid_num) 
x_normalized2 = transformer.transform(X_valid_num)
print(x_normalized2.shape)
x_normalized3 = pd.DataFrame(x_normalized2, columns=X_valid_num.columns)
x_normalized3

# %% [markdown]
# ### Encoding Categorical Data.

# %% [markdown]
# ### Splitting into train set and test set.

# %% [markdown]
# ## Modeling.

# %% [markdown]
# ### Apply model.

# %% [markdown]
# ## R2

# %% [markdown]
# ### MSE.

# %% [markdown]
# ### RMSE.

# %% [markdown]
# ### MAE.
